# %%
import pandas as pd
import numpy as np 
import requests
from data.data_engineering import get_location, column_selection, distance_calculation
import streamlit as st
import folium
from folium import plugins
import streamlit_folium as st_folium
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [312], line 9
#       7 from folium import plugins
#       8 import streamlit_folium as st_folium
# ----> 9 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
#to get details from a certain stop: 
url = 'https://v5.bvg.transport.rest/locations?'
params = {'poi' : 'false', 
          'adresses' : 'false',
          'query' : 'mehringdamm'
         }
data = requests.get(url,params)
location = get_location('Obentrautstraße 71')

# %%
latitude = round(location[0],3)
longitude = round(location[1],3)

# %%
url_nearby = 'https://v5.bvg.transport.rest/stops/nearby?'
params_ = {'latitude' : latitude,
          'longitude' : longitude
         }

# %%
#request, to get the closest train stations: 
data_1 = requests.get(url_nearby,params_)

# %%
query = data_1.json()

# %%
df_name = []
df_lat = []
df_lon = []
df_dist = []
types = []

# %%
keys = list(query[0]['products'].keys())

# %%
for i in range(len(query)): 
    df_name.append(query[i]['name'])
    df_lat.append(query[i]['location']['latitude'])
    df_lon.append(query[i]['location']['longitude'])
    df_dist.append(query[i]['distance'])

# %%
df_nearby = pd.DataFrame()
df_nearby['name'] = df_name
df_nearby['lat'] = df_lat
df_nearby['lon'] = df_lon
df_nearby['dist'] = df_dist

# %%
for i in range(len(query)): 
    for x in range(len(keys)): 
        if query[i]['products'][keys[x]] == True: 
            print(query[i]['name'])
            types.append(keys[x])
            print(types)
# Out:
# U Möckernbrücke
# ['subway']
# U Möckernbrücke
# ['subway', 'bus']
# Hornstr
# ['subway', 'bus', 'bus']
# U Gleisdreieck
# ['subway', 'bus', 'bus', 'subway']
# Mehringbrücke
# ['subway', 'bus', 'bus', 'subway', 'bus']
# Willy-Brandt-Haus
# ['subway', 'bus', 'bus', 'subway', 'bus', 'bus']
# Obentrautstr./U Mehringdamm
# ['subway', 'bus', 'bus', 'subway', 'bus', 'bus', 'bus']
# U Mehringdamm
# ['subway', 'bus', 'bus', 'subway', 'bus', 'bus', 'bus', 'subway']
# U Mehringdamm
# ['subway', 'bus', 'bus', 'subway', 'bus', 'bus', 'bus', 'subway', 'bus']
# U Hallesches Tor
# ['subway', 'bus', 'bus', 'subway', 'bus', 'bus', 'bus', 'subway', 'bus', 'subway']
# U Hallesches Tor
# ['subway', 'bus', 'bus', 'subway', 'bus', 'bus', 'bus', 'subway', 'bus', 'subway', 'bus']

# %%
df_nearby['walking time'] = round(df_nearby['dist'].apply(lambda x: (x*60)/7000),2)

# %%
df_nearby
# Out:
#                           name        lat        lon  dist  walking time
# 0              U Möckernbrücke  52.498945  13.383257   264          2.26
# 1                      Hornstr  52.493633  13.383823   420          3.60
# 2               U Gleisdreieck  52.499583  13.374295   537          4.60
# 3                Mehringbrücke  52.497974  13.389262   569          4.88
# 4            Willy-Brandt-Haus  52.500411  13.387437   577          4.95
# 5  Obentrautstr./U Mehringdamm  52.495350  13.389612   611          5.24
# 6                U Mehringdamm  52.493570  13.388138   616          5.28
# 7             U Hallesches Tor  52.497777  13.391761   733          6.28

# %%
type(location[0])
# Out:
# float

# %%
latitude = 52.52446
longitude = 13.40812
base = 'https://v5.bvg.transport.rest/stops/reachable-from?'
params_1 = {'latitude' : location[0],
            'longitude' : location[1],
            'address' : 'Obentrautstr.+71',
            'maxDuration' : 10
           }

# %%
query_1 = requests.get(base,params_1).json()

# %%
query_1
# Out:
# [{'duration': 6,
#   'stations': [{'type': 'stop',
#     'id': '900000017104',
#     'name': 'U Möckernbrücke',
#     'location': {'type': 'location',
#      'id': '900017104',
#      'latitude': 52.498945,
#      'longitude': 13.383257},
#     'products': {'suburban': False,
#      'subway': True,
#      'tram': False,
#      'bus': True,
#      'ferry': False,
#      'express': False,
#      'regional': False},
#     'stationDHID': 'de:11000:900017104'}]},
#  {'duration': 7,
#   'stations': [{'type': 'stop',
#     'id': '900000058103',
#     'name': 'S+U Yorckstr.',
#     'location': {'type': 'location',
#      'id': '900058103',
#      'latitude': 52.492392,
#      'longitude': 13.372227},
#     'products': {'suburban': True,
#      'subway': True,
#      'tram': False,
#      'bus': True,
#      'ferry': False,
#      'express': False,
#      'regional': False},
#     'stationDHID': 'de:11000:900058103'}]},
#  {'duration': 8,
#   'stations': [{'type': 'stop',
#     'id': '900000012103',
#     'name': 'U Hallesches Tor',
#     'location': {'type': 'location',
#      'id': '900012103',
#      'latitude': 52.497777,
#      'longitude': 13.391761},
#     'products': {'suburban': False,
#      'subway': True,
#      'tram': False,
#      'bus': True,
#      'ferry': False,
#      'express': False,
#      'regional': False},
#     'stationDHID': 'de:11000:900012103'},
#    {'type': 'stop',
#     'id': '900000017100',
#     'name': 'Obentrautstr./U Mehringdamm',
#     'location': {'type': 'location',
#      'id': '900017100',
#      'latitude': 52.49535,
#      'longitude': 13.389612},
#     'products': {'suburban': False,
#      'subway': False,
#      'tram': False,
#      'bus': True,
#      'ferry': False,
#      'express': False,
#      'regional': False},
#     'stationDHID': 'de:11000:900017100'},
#    {'type': 'stop',
#     'id': '900000017101',
#     'name': 'U Mehringdamm',
#     'location': {'type': 'location',
#      'id': '900017101',
#      'latitude': 52.49357,
#      'longitude': 13.388138},
#     'products': {'suburban': False,
#      'subway': True,
#      'tram': False,
#      'bus': True,
#      'ferry': False,
#      'express': False,
#      'regional': False},
#     'stationDHID': 'de:11000:900017101'},
#    {'type': 'stop',
#     'id': '900000017103',
#     'name': 'U Gleisdreieck',
#     'location': {'type': 'location',
#      'id': '900017103',
#      'latitude': 52.499583,
#      'longitude': 13.374295},
#     'products': {'suburban': False,
#      'subway': True,
#      'tram': False,
#      'bus': False,
#      'ferry': False,
#      'express': False,
#      'regional': False},
#     'stationDHID': 'de:11000:900017103'},
#    {'type': 'stop',
#     'id': '900000017105',
#     'name': 'Hornstr',
#     'location': {'type': 'location',
#      'id': '900017105',
#      'latitude': 52.493633,
#      'longitude': 13.383823},
#     'products': {'suburban': False,
#      'subway': False,
#      'tram': False,
#      'bus': True,
#      'ferry': False,
#      'express': False,
#      'regional': False},
#     'stationDHID': 'de:11000:900017105'}]},
#  {'duration': 9,
#   'stations': [{'type': 'stop',
#     'id': '900000005253',
#     'name': 'Schöneberger Brücke',
#     'location': {'type': 'location',
#      'id': '900005253',
#      'latitude': 52.502334,
#      'longitude': 13.377747},
#     'products': {'suburban': False,
#      'subway': False,
#      'tram': False,
#      'bus': True,
#      'ferry': False,
#      'express': False,
#      'regional': False},
#     'stationDHID': 'de:11000:900005253'},
#    {'type': 'stop',
#     'id': '900000012106',
#     'name': 'Mehringbrücke',
#     'location': {'type': 'location',
#      'id': '900012106',
#      'latitude': 52.497974,
#      'longitude': 13.389262},
#     'products': {'suburban': False,
#      'subway': False,
#      'tram': False,
#      'bus': True,
#      'ferry': False,
#      'express': False,
#      'regional': False},
#     'stationDHID': 'de:11000:900012106'},
#    {'type': 'stop',
#     'id': '900000054102',
#     'name': 'U Kleistpark',
#     'location': {'type': 'location',
#      'id': '900054102',
#      'latitude': 52.490684,
#      'longitude': 13.360541},
#     'products': {'suburban': False,
#      'subway': True,
#      'tram': False,
#      'bus': True,
#      'ferry': False,
#      'express': False,
#      'regional': False},
#     'stationDHID': 'de:11000:900054102'},
#    {'type': 'stop',
#     'id': '900000057155',
#     'name': 'Katzbachstr.',
#     'location': {'type': 'location',
#      'id': '900057155',
#      'latitude': 52.491817,
#      'longitude': 13.378025},
#     'products': {'suburban': False,
#      'subway': False,
#      'tram': False,
#      'bus': True,
#      'ferry': False,
#      'express': False,
#      'regional': False},
#     'stationDHID': 'de:11000:900057155'}]},
#  {'duration': 10,
#   'stations': [{'type': 'stop',
#     'id': '900000005201',
#     'name': 'U Kurfürstenstr.',
#     'location': {'type': 'location',
#      'id': '900005201',
#      'latitude': 52.499781,
#      'longitude': 13.362861},
#     'products': {'suburban': False,
#      'subway': True,
#      'tram': False,
#      'bus': True,
#      'ferry': False,
#      'express': False,
#      'regional': False},
#     'stationDHID': 'de:11000:900005201'},
#    {'type': 'stop',
#     'id': '900000013103',
#     'name': 'U Prinzenstr.',
#     'location': {'type': 'location',
#      'id': '900013103',
#      'latitude': 52.498325,
#      'longitude': 13.406548},
#     'products': {'suburban': False,
#      'subway': True,
#      'tram': False,
#      'bus': True,
#      'ferry': False,
#      'express': False,
#      'regional': False},
#     'stationDHID': 'de:11000:900013103'},
#    {'type': 'stop',
#     'id': '900000016101',
#     'name': 'U Gneisenaustr.',
#     'location': {'type': 'location',
#      'id': '900016101',
#      'latitude': 52.49125,
#      'longitude': 13.395384},
#     'products': {'suburban': False,
#      'subway': True,
#      'tram': False,
#      'bus': True,
#      'ferry': False,
#      'express': False,
#      'regional': False},
#     'stationDHID': 'de:11000:900016101'},
#    {'type': 'stop',
#     'id': '900000017102',
#     'name': 'U Platz der Luftbrücke',
#     'location': {'type': 'location',
#      'id': '900017102',
#      'latitude': 52.484868,
#      'longitude': 13.385927},
#     'products': {'suburban': False,
#      'subway': True,
#      'tram': False,
#      'bus': True,
#      'ferry': False,
#      'express': False,
#      'regional': False},
#     'stationDHID': 'de:11000:900017102'},
#    {'type': 'stop',
#     'id': '900000017152',
#     'name': 'Kreuzberg/Wasserfall',
#     'location': {'type': 'location',
#      'id': '900017152',
#      'latitude': 52.490172,
#      'longitude': 13.382331},
#     'products': {'suburban': False,
#      'subway': False,
#      'tram': False,
#      'bus': True,
#      'ferry': False,
#      'express': False,
#      'regional': False},
#     'stationDHID': 'de:11000:900017152'},
#    {'type': 'stop',
#     'id': '900000054103',
#     'name': 'U Eisenacher Str.',
#     'location': {'type': 'location',
#      'id': '900054103',
#      'latitude': 52.48948,
#      'longitude': 13.350285},
#     'products': {'suburban': False,
#      'subway': True,
#      'tram': False,
#      'bus': True,
#      'ferry': False,
#      'express': False,
#      'regional': False},
#     'stationDHID': 'de:11000:900054103'}]}]

# %%
duration = []
stations = []
lat_station = []
lon_station = []
for i in range(len(query_1)):
    duration.append(query_1[i]['duration'])
    for x in range(len(query_1[i]['stations'])):
        stations.append((query_1[i]['duration'],query_1[i]['stations'][x]['name']))
        lat_station.append(query_1[i]['stations'][x]['location']['latitude'])
        lon_station.append(query_1[i]['stations'][x]['location']['longitude'])

# %%
stations
# Out:
# [(6, 'U Möckernbrücke'),
#  (7, 'S+U Yorckstr.'),
#  (8, 'U Hallesches Tor'),
#  (8, 'Obentrautstr./U Mehringdamm'),
#  (8, 'U Mehringdamm'),
#  (8, 'U Gleisdreieck'),
#  (8, 'Hornstr'),
#  (9, 'Schöneberger Brücke'),
#  (9, 'Mehringbrücke'),
#  (9, 'U Kleistpark'),
#  (9, 'Katzbachstr.'),
#  (10, 'U Kurfürstenstr.'),
#  (10, 'U Prinzenstr.'),
#  (10, 'U Gneisenaustr.'),
#  (10, 'U Platz der Luftbrücke'),
#  (10, 'Kreuzberg/Wasserfall'),
#  (10, 'U Eisenacher Str.')]

# %%
journey = pd.DataFrame()

# %%
journey['stations'] = stations

# %%
#now we split the values, in order to get a dataframe, that we can make use of. 
journey = pd.DataFrame(journey['stations'].tolist(), index=journey.index).rename(columns = {0: 'minutes', 1:'station'})

# %%
journey['lat'] = lat_station
journey['lon'] = lon_station
journey_8 = journey[journey['minutes']<8]
journey_10 = journey[journey['minutes']<11]
journey_10 = journey_10[journey_10['minutes']>8].reset_index()

# %%
journey_10
# Out:
#    index  minutes                 station        lat        lon
# 0      7        9     Schöneberger Brücke  52.502334  13.377747
# 1      8        9           Mehringbrücke  52.497974  13.389262
# 2      9        9            U Kleistpark  52.490684  13.360541
# 3     10        9            Katzbachstr.  52.491817  13.378025
# 4     11       10        U Kurfürstenstr.  52.499781  13.362861
# 5     12       10           U Prinzenstr.  52.498325  13.406548
# 6     13       10         U Gneisenaustr.  52.491250  13.395384
# 7     14       10  U Platz der Luftbrücke  52.484868  13.385927
# 8     15       10    Kreuzberg/Wasserfall  52.490172  13.382331
# 9     16       10       U Eisenacher Str.  52.489480  13.350285

# %%
m = folium.Map(location =location)

# %%
for i in range(len(journey)):
    folium.Marker([journey.lat[i],
                    journey.lon[i]],
                    popup = journey['station'][i],
                    icon = folium.Icon(color = 'red',
                                        icon = 'info-sign')).add_to(m)

# %%
da = []
for i in range(len(journey_10)):
    da.append((journey_10['lat'][i],journey_10['lon'][i]))

# %%
type(da)
# Out:
# list

# %%
folium.Polygon(da, noClip= True).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94e708ada744c7651d90aa36fbc7a550 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94e708ada744c7651d90aa36fbc7a550&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94e708ada744c7651d90aa36fbc7a550 = L.map(
#                 &quot;map_94e708ada744c7651d90aa36fbc7a550&quot;,
#                 {
#                     center: [52.4969709, 13.380662692437785],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef9feb6a560b572535c85be034d26816 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_94e708ada744c7651d90aa36fbc7a550);
#
#
#             var marker_58c690e6dfddc68c52e91a1f8e09b970 = L.marker(
#                 [52.498945, 13.383257],
#                 {}
#             ).addTo(map_94e708ada744c7651d90aa36fbc7a550);
#
#
#             var icon_0d9f7bd96768078ca7133a3fe866e5d9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_58c690e6dfddc68c52e91a1f8e09b970.setIcon(icon_0d9f7bd96768078ca7133a3fe866e5d9);
#
#
#         var popup_02603b6082f2698aef1245b4ae48049f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aacb2ab3d1b9b224378e7b1d8e72daef = $(`&lt;div id=&quot;html_aacb2ab3d1b9b224378e7b1d8e72daef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;U Möckernbrücke&lt;/div&gt;`)[0];
#                 popup_02603b6082f2698aef1245b4ae48049f.setContent(html_aacb2ab3d1b9b224378e7b1d8e72daef);
#
#
#
#         marker_58c690e6dfddc68c52e91a1f8e09b970.bindPopup(popup_02603b6082f2698aef1245b4ae48049f)
#         ;
#
#
#
#
#             var marker_8fcb6d3b2ab17c40c0e220e9cd49915c = L.marker(
#                 [52.492392, 13.372227],
#                 {}
#             ).addTo(map_94e708ada744c7651d90aa36fbc7a550);
#
#
#             var icon_c9abb62756c7b933d464fddd64525ba3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8fcb6d3b2ab17c40c0e220e9cd49915c.setIcon(icon_c9abb62756c7b933d464fddd64525ba3);
#
#
#         var popup_73756869ff480b26cbffa88b7b1a567c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a4594f6c3fc1177ab6aba8a1687fcde = $(`&lt;div id=&quot;html_7a4594f6c3fc1177ab6aba8a1687fcde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;S+U Yorckstr.&lt;/div&gt;`)[0];
#                 popup_73756869ff480b26cbffa88b7b1a567c.setContent(html_7a4594f6c3fc1177ab6aba8a1687fcde);
#
#
#
#         marker_8fcb6d3b2ab17c40c0e220e9cd49915c.bindPopup(popup_73756869ff480b26cbffa88b7b1a567c)
#         ;
#
#
#
#
#             var marker_83bf08324122c614f64a74189b57165c = L.marker(
#                 [52.497777, 13.391761],
#                 {}
#             ).addTo(map_94e708ada744c7651d90aa36fbc7a550);
#
#
#             var icon_9021b948bb29a7b4a54532a0199c7c41 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_83bf08324122c614f64a74189b57165c.setIcon(icon_9021b948bb29a7b4a54532a0199c7c41);
#
#
#         var popup_5565d7c8e0700852921c6becab6a0c5c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54d71083b458b1ea4310b8c84e6941bf = $(`&lt;div id=&quot;html_54d71083b458b1ea4310b8c84e6941bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;U Hallesches Tor&lt;/div&gt;`)[0];
#                 popup_5565d7c8e0700852921c6becab6a0c5c.setContent(html_54d71083b458b1ea4310b8c84e6941bf);
#
#
#
#         marker_83bf08324122c614f64a74189b57165c.bindPopup(popup_5565d7c8e0700852921c6becab6a0c5c)
#         ;
#
#
#
#
#             var marker_edf22935eab34d79e47ed83862d98f13 = L.marker(
#                 [52.49535, 13.389612],
#                 {}
#             ).addTo(map_94e708ada744c7651d90aa36fbc7a550);
#
#
#             var icon_d1ea10dd6667c36b8cfb53c7f9361d77 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix
